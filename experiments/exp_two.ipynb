# %%
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch import nn 
from torch.utils.data import Subset

import json

# %%
train_idx = json.load(
    open("../preprocessed/train_indices.json")
)

val_idx = json.load(
    open("../preprocessed/val_indices.json")
)

# %%
transform = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.ToTensor(), 
        transforms.RandomHorizontalFlip(), 
        transforms.RandomRotation(30),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]
)

dataset = ImageFolder(
    root="../data", 
    transform=transform
)

train_dataset = Subset(dataset, train_idx)
val_dataset = Subset(dataset, val_idx)

# %%
train_dataset[0]
# Out:
# (tensor([[[-0.1828, -0.1999, -0.0287,  ...,  0.1768,  0.5364,  0.4337],
#           [-0.1486, -0.0801, -0.1999,  ...,  0.6392,  0.5878,  0.5193],
#           [-0.1999,  0.0398, -0.0629,  ...,  0.4508,  0.1597,  0.4851],
#           ...,
#           [-0.1314, -0.2171, -0.3541,  ...,  0.1939,  0.1597,  0.2624],
#           [-0.3027,  0.3652, -0.1999,  ...,  0.4851,  0.1939,  0.1939],
#           [ 0.0227,  0.1597,  0.0056,  ...,  0.5878,  0.3138,  0.3652]],
#
#          [[-0.3200, -0.3375, -0.1625,  ...,  0.0826,  0.4503,  0.3452],
#           [-0.2850, -0.2150, -0.3375,  ...,  0.5553,  0.5028,  0.4328],
#           [-0.3375, -0.0924, -0.1975,  ...,  0.3627,  0.0651,  0.3978],
#           ...,
#           [-0.2150, -0.3025, -0.4426,  ...,  0.1877,  0.1527,  0.2577],
#           [-0.3901,  0.2927, -0.2850,  ...,  0.4853,  0.1877,  0.1877],
#           [-0.0574,  0.0826, -0.0749,  ...,  0.5903,  0.3102,  0.3627]],
#
#          [[-0.0092, -0.0267,  0.1476,  ...,  0.4265,  0.7925,  0.6879],
#           [ 0.0256,  0.0953, -0.0267,  ...,  0.8971,  0.8448,  0.7751],
#           [-0.0267,  0.2173,  0.1128,  ...,  0.7054,  0.4091,  0.7402],
#           ...,
#           [ 0.2522,  0.1651,  0.0256,  ...,  0.6705,  0.6356,  0.7402],
#           [ 0.0779,  0.7576,  0.1825,  ...,  0.9668,  0.6705,  0.6705],
#           [ 0.4091,  0.5485,  0.3916,  ...,  1.0714,  0.7925,  0.8448]]]),
#  5)
