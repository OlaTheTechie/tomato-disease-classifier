# %%
from src.dataset import (
    load_dataset, 
    split_dataset, 
    load_preprocessed, 
    save_preprocessed_data
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.dataset import (
#       2     load_dataset,
#       3     split_dataset,
#       4     load_preprocessed,
#       5     save_preprocessed_data
#       6 )
#
# ModuleNotFoundError: No module named 'src'
